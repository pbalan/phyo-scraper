# %%
import io, os, sys, types

from IPython import get_ipython
from nbformat import read
from IPython.core.interactiveshell import InteractiveShell

def find_notebook(fullname, path=None):
    """find a notebook, given its fully qualified name and an optional path

    This turns "foo.bar" into "foo/bar.ipynb"
    and tries turning "Foo_Bar" into "Foo Bar" if Foo_Bar
    does not exist.
    """
    name = fullname.rsplit('.', 1)[-1]
    if not path:
        path = ['']
    for d in path:
        nb_path = os.path.join(d, name + ".ipynb")
        if os.path.isfile(nb_path):
            return nb_path
        # let import Notebook_Name find "Notebook Name.ipynb"
        nb_path = nb_path.replace("_", " ")
        if os.path.isfile(nb_path):
            return nb_path

class NotebookLoader(object):
    """Module Loader for Jupyter Notebooks"""
    def __init__(self, path=None):
        self.shell = InteractiveShell.instance()
        self.path = path

    def load_module(self, fullname):
        """import a notebook as a module"""
        path = find_notebook(fullname, self.path)

        print ("importing Jupyter notebook from %s" % path)

        # load the notebook object
        with io.open(path, 'r', encoding='utf-8') as f:
            nb = read(f, 4)


        # create the module and add it to sys.modules
        # if name in sys.modules:
        #    return sys.modules[name]
        mod = types.ModuleType(fullname)
        mod.__file__ = path
        mod.__loader__ = self
        mod.__dict__['get_ipython'] = get_ipython
        sys.modules[fullname] = mod

        # extra work to ensure that magics that would affect the user_ns
        # actually affect the notebook module's ns
        save_user_ns = self.shell.user_ns
        self.shell.user_ns = mod.__dict__

        try:
            for cell in nb.cells:
                if cell.cell_type == 'code':
                    # transform the input to executable Python
                    code = self.shell.input_transformer_manager.transform_cell(cell.source)
                    # run the code in themodule
                    exec(code, mod.__dict__)
        finally:
            self.shell.user_ns = save_user_ns
        return mod

class NotebookFinder(object):
    """Module finder that locates Jupyter Notebooks"""
    def __init__(self):
        self.loaders = {}

    def find_module(self, fullname, path=None):
        nb_path = find_notebook(fullname, path)
        if not nb_path:
            return

        key = path
        if path:
            # lists aren't hashable
            key = os.path.sep.join(path)

        if key not in self.loaders:
            self.loaders[key] = NotebookLoader(path)
        return self.loaders[key]


sys.meta_path.append(NotebookFinder())

# %%
from urllib2 import urlopen, HTTPError, URLError
from urlparse import urlparse
from bs4 import BeautifulSoup
from strategy.ScraperContactUs import ScraperContactUs
from ExcelHandler import ExcelHandler

class Scraper(object):
    'Scraper to scrape the website'
    emails = 0
    domain = None
    
    def __init__(self, webpageUrl):
        self.webpageUrl = webpageUrl
        self.domain = self.getDomain(webpageUrl)
    
    def setWebpageUrl(self, webpageUrl):
        self.webpageUrl = webpageUrl
    
    def getWebpageUrl(self):
        return self.webpageUrl
    
    def makeSoup(self, webpageUrl = None):
        try:
            if (webpageUrl != None):
                # print webpageUrl
                page = urlopen(webpageUrl).read()
            else:
                page = urlopen(self.webpageUrl).read()
            soup = BeautifulSoup(page, "lxml")
            return soup
        except HTTPError, ex:
            print 'The server couldn\'t fulfill the request for %s.' % self.webpageUrl
            print 'Error code: ', ex.code
            return False
        except URLError, ex:
            print 'We failed to reach a server for %s.' % self.webpageUrl
            print 'Reason: ', ex.reason
            return False 
    
    def makeTextSoup(self, text):
        soup = BeautifulSoup(text, "lxml")
        return soup
    
    def getDomain(self, webpageUrl):
        parsedUri = urlparse(webpageUrl)
        return '{uri.scheme}://{uri.netloc}'.format(uri=parsedUri)
# Out:
# importing Jupyter notebook from strategy/ScraperContactUs.ipynb
# importing Jupyter notebook from ExcelHandler.ipynb

# %%
# Read excel
# 05 - email
# l2 - website

wb = ExcelHandler('haha.xlsx')
ws = wb.getSheet('Sheet1')
rorieList = wb.getDataInColumns([5, 6])

print "processing Rorie List..."

for data in rorieList:
    try:
        if (data[0] == None and data[1] != None):
            scraper = Scraper(data[1])
            soup = scraper.makeSoup()
            if (soup == False):
                continue
            contactUs = ScraperContactUs(soup, scraper)

            # Get contact-us links
            contactUs.getContactLinks()
            # Get impressum links
            contactUs.getImpressumLinks()

            # check if the strategy worked i.e. the links were found
            if (contactUs.getLinkCount() > 0):
                contactUs.findEmail()
                if (contactUs.getEmailCount() > 0):
                    # save to database
                    print ', '.join(contactUs.emails)
    except:
        print "Unable to open this link: " + data[1]

print "done!"
# Out:
# processing Rorie List...
# The server couldn't fulfill the request for http://oldwww.upol.cz/resources/jointlab/.
# Error code:  404
# The server couldn't fulfill the request for http://rco.upol.cz/index_en.html.
# Error code:  404
# Unable to open this link: http://www.pall.es
# We failed to reach a server for http://www.pall.com.
# Reason:  [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:661)
# We failed to reach a server for http://www.pall.com.
# Reason:  [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:661)
# We failed to reach a server for http://www.pall.com.
# Reason:  [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:661)
# We failed to reach a server for http://www.pall.com.
# Reason:  [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:661)
# We failed to reach a server for http://www.pall.com.
# Reason:  [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:661)
# Unable to open this link: http://www.palomartechnologies.com
# The server couldn't fulfill the request for http://www.pavdata.com.
# Error code:  403
# Unable to open this link: www.pc-lasers.com
# The server couldn't fulfill the request for http://www.pco.de.
# Error code:  404
# Unable to open this link: http://www.pco.de
# jQuery(window).load(function(){
#
# 		var styles = [
# 			{
# 				stylers: [
# 					{ hue: "#596b79" },
# 					{ saturation: "-50" },
# 					{ lightness: "0" },
# 				]
# 			},
# 			{ featureType: "landscape", stylers: [
# 					{ hue: "#3f7644"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "administrative", stylers: [
# 					{ hue: "#76723f"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "road", stylers: [
# 					{ hue: "#c9aa78"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "water", stylers: [
# 					{ hue: ""},
# 					{ saturation: ""},
# 					{ lightness: ""},
# 				]
# 			},
# 			{ featureType: "poi", stylers: [
# 					{ hue: "#7a6d3d"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 		];
#
# 		jQuery("#elm-google-map-35-container").gmap3({
# 			map:{
# 				address: '125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE',
# 				options:{
#
# 					mapTypeId: google.maps.MapTypeId.ROADMAP,
# 					zoom: 2,
# 					scrollwheel: false,
# 					styles: styles,
# 				}
# 			},
# 			marker:{
# 				values:[
# 											{
# 							address: "125, rue François Gernelle, 84120 Pertuis ,FRANCE",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST headquarters</h3><p>125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE.  +33 (0) 4 90 09 47 90</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Londres",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  UK & Ireland</h3><p>Luc Mallinger - Phone: +44 77 03 61 18 27     contact.uk@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Wroclaw",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST Poland, Central & Eastern Europe</h3><p> Rafal Firgang   -  Phone: +48 692 388 946      contact.cee@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Saragosse, Espagne",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Spain & Portugal</h3><p> José Luis Izquierdo  -  Phone: +34 620 296 739     contact.spain@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "São Paulo, Brésil",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Brazil</h3><p>Etimo Ferreira   -  Phone: +55 11 975 961 068       contact-brasil@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Japan 〒100-8111 Tōkyō-to, Chiyoda-ku, Uchikanda, 1 Chome−5−15",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST   Japan KK</h3><p>Yoshifumi Kato -       Arte Otemachi 10F 1-5-16 Uchikanda, Chiyoda-ku TOKYO 101-0047 JAPAN      PHONE : +81 3 3233 2150 contact.japan@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "1299 Schlumberger Drive Fort Mill SC 29715 USA",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  North America</h3><p>Gregor Veeser, Jeff Fountain, Greg Mattioli      -             1299 Schlumberger Drive Fort Mill SC 29715 USA     PHONE : +1 803 396 3990 contact.usa@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Bologna, italy",
# 							data: '<div class="gmap-infowindow-content"><h3>Pellenc ST  Italy</h3><p>Beppe Eliantonio   -   Phone: +39 349 6161 359 contact.italy@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Mexico city, mexico",
# 							data: '<div class="gmap-infowindow-content"><h3>Mexico</h3><p>contact.mexico@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Turkey",
# 							data: '<div class="gmap-infowindow-content"><h3>Turkey</h3><p>contact.turkey@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Israel",
# 							data: '<div class="gmap-infowindow-content"><h3>Israel</h3><p>contact.israel@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "South Korea",
# 							data: '<div class="gmap-infowindow-content"><h3>South Korea</h3><p>contact.southkorea@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "shanghai, china",
# 							data: '<div class="gmap-infowindow-content"><h3>China</h3><p>contact.china@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "New York, USA",
# 							data: '<div class="gmap-infowindow-content"><h3>North America</h3><p></p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 				],
# 				options:{
# 					draggable: false
# 				},
# 				events:{
# 					click: function(marker, event, context){
# 						var map = jQuery(this).gmap3("get"),
# 						infowindow = jQuery(this).gmap3({ get:{ name:"infowindow" } });
# 						if (infowindow){
# 							infowindow.open(map, marker);
# 							infowindow.setContent(context.data);
# 						} else {
# 							jQuery(this).gmap3({
# 								infowindow:{
# 									anchor:marker,
# 									options:{ content: context.data }
# 								}
# 							});
# 						}
# 					},
# 				},
# 			}
# 		});
#
# 			if(!isResponsive(1024)){
# 				jQuery("#elm-google-map-35").waypoint(function(){
# 					jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 				}, { triggerOnce: true, offset: "95%" });
# 			} else {
# 				jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 			}
# 	});
# The server couldn't fulfill the request for http://www.pentax.fr.
# Error code:  404
# Unable to open this link: http://www.pentax.fr
# The server couldn't fulfill the request for http://www.optoelectronics.perkinelmer.com.
# Error code:  400
# The server couldn't fulfill the request for http://www.pertech.fr/.
# Error code:  403
# Unable to open this link: www.petrotest.com
# jQuery(window).load(function(){
#
# 		var styles = [
# 			{
# 				stylers: [
# 					{ hue: "#596b79" },
# 					{ saturation: "-50" },
# 					{ lightness: "0" },
# 				]
# 			},
# 			{ featureType: "landscape", stylers: [
# 					{ hue: "#3f7644"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "administrative", stylers: [
# 					{ hue: "#76723f"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "road", stylers: [
# 					{ hue: "#c9aa78"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "water", stylers: [
# 					{ hue: ""},
# 					{ saturation: ""},
# 					{ lightness: ""},
# 				]
# 			},
# 			{ featureType: "poi", stylers: [
# 					{ hue: "#7a6d3d"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 		];
#
# 		jQuery("#elm-google-map-35-container").gmap3({
# 			map:{
# 				address: '125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE',
# 				options:{
#
# 					mapTypeId: google.maps.MapTypeId.ROADMAP,
# 					zoom: 2,
# 					scrollwheel: false,
# 					styles: styles,
# 				}
# 			},
# 			marker:{
# 				values:[
# 											{
# 							address: "125, rue François Gernelle, 84120 Pertuis ,FRANCE",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST headquarters</h3><p>125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE.  +33 (0) 4 90 09 47 90</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Londres",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  UK & Ireland</h3><p>Luc Mallinger - Phone: +44 77 03 61 18 27     contact.uk@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Wroclaw",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST Poland, Central & Eastern Europe</h3><p> Rafal Firgang   -  Phone: +48 692 388 946      contact.cee@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Saragosse, Espagne",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Spain & Portugal</h3><p> José Luis Izquierdo  -  Phone: +34 620 296 739     contact.spain@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "São Paulo, Brésil",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Brazil</h3><p>Etimo Ferreira   -  Phone: +55 11 975 961 068       contact-brasil@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Japan 〒100-8111 Tōkyō-to, Chiyoda-ku, Uchikanda, 1 Chome−5−15",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST   Japan KK</h3><p>Yoshifumi Kato -       Arte Otemachi 10F 1-5-16 Uchikanda, Chiyoda-ku TOKYO 101-0047 JAPAN      PHONE : +81 3 3233 2150 contact.japan@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "1299 Schlumberger Drive Fort Mill SC 29715 USA",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  North America</h3><p>Gregor Veeser, Jeff Fountain, Greg Mattioli      -             1299 Schlumberger Drive Fort Mill SC 29715 USA     PHONE : +1 803 396 3990 contact.usa@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Bologna, italy",
# 							data: '<div class="gmap-infowindow-content"><h3>Pellenc ST  Italy</h3><p>Beppe Eliantonio   -   Phone: +39 349 6161 359 contact.italy@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Mexico city, mexico",
# 							data: '<div class="gmap-infowindow-content"><h3>Mexico</h3><p>contact.mexico@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Turkey",
# 							data: '<div class="gmap-infowindow-content"><h3>Turkey</h3><p>contact.turkey@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Israel",
# 							data: '<div class="gmap-infowindow-content"><h3>Israel</h3><p>contact.israel@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "South Korea",
# 							data: '<div class="gmap-infowindow-content"><h3>South Korea</h3><p>contact.southkorea@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "shanghai, china",
# 							data: '<div class="gmap-infowindow-content"><h3>China</h3><p>contact.china@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "New York, USA",
# 							data: '<div class="gmap-infowindow-content"><h3>North America</h3><p></p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 				],
# 				options:{
# 					draggable: false
# 				},
# 				events:{
# 					click: function(marker, event, context){
# 						var map = jQuery(this).gmap3("get"),
# 						infowindow = jQuery(this).gmap3({ get:{ name:"infowindow" } });
# 						if (infowindow){
# 							infowindow.open(map, marker);
# 							infowindow.setContent(context.data);
# 						} else {
# 							jQuery(this).gmap3({
# 								infowindow:{
# 									anchor:marker,
# 									options:{ content: context.data }
# 								}
# 							});
# 						}
# 					},
# 				},
# 			}
# 		});
#
# 			if(!isResponsive(1024)){
# 				jQuery("#elm-google-map-35").waypoint(function(){
# 					jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 				}, { triggerOnce: true, offset: "95%" });
# 			} else {
# 				jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 			}
# 	});, prashant_balan@apple.com, If you did not receive a copy of the PHP license, or have any questions about PHP licensing, please contact license@php.net.
# The server couldn't fulfill the request for http://www.apptech.philips.com.
# Error code:  404
# Unable to open this link: http://www.apptech.philips.com
# The server couldn't fulfill the request for http://www.philips.be/About/company.
# Error code:  404
# Unable to open this link: http://www.philips.be/About/company
# The server couldn't fulfill the request for http://www.philips.be/About/company.
# Error code:  404
# Unable to open this link: http://www.philips.be/About/company
# The server couldn't fulfill the request for http://www.philips.it.
# Error code:  404
# Unable to open this link: http://www.philips.it
# The server couldn't fulfill the request for http://www.philips.be/About/company.
# Error code:  404
# Unable to open this link: http://www.philips.be/About/company
# The server couldn't fulfill the request for http://www.philips.com.
# Error code:  404
# Unable to open this link: http://www.philips.com
# The server couldn't fulfill the request for http://www.research.philips.com.
# Error code:  404
# Unable to open this link: http://www.research.philips.com
# We failed to reach a server for http://www.phoenix-xray.com/de.
# Reason:  [Errno 8] nodename nor servname provided, or not known
# The server couldn't fulfill the request for http://www.phonelink-inst.co.uk.
# Error code:  403
# The server couldn't fulfill the request for http://www.rhenaphotonics.fr/en/content/governance.
# Error code:  404
# Unable to open this link: http://www.photeon.com
# The server couldn't fulfill the request for http://www.photline.com/.
# Error code:  404
# Unable to open this link: http://www.photline.com/
# The server couldn't fulfill the request for http://www.photond.com.
# Error code:  403
# Unable to open this link: www.LM.PhotonAG.com
# jQuery(window).load(function(){
#
# 		var styles = [
# 			{
# 				stylers: [
# 					{ hue: "#596b79" },
# 					{ saturation: "-50" },
# 					{ lightness: "0" },
# 				]
# 			},
# 			{ featureType: "landscape", stylers: [
# 					{ hue: "#3f7644"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "administrative", stylers: [
# 					{ hue: "#76723f"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "road", stylers: [
# 					{ hue: "#c9aa78"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "water", stylers: [
# 					{ hue: ""},
# 					{ saturation: ""},
# 					{ lightness: ""},
# 				]
# 			},
# 			{ featureType: "poi", stylers: [
# 					{ hue: "#7a6d3d"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 		];
#
# 		jQuery("#elm-google-map-35-container").gmap3({
# 			map:{
# 				address: '125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE',
# 				options:{
#
# 					mapTypeId: google.maps.MapTypeId.ROADMAP,
# 					zoom: 2,
# 					scrollwheel: false,
# 					styles: styles,
# 				}
# 			},
# 			marker:{
# 				values:[
# 											{
# 							address: "125, rue François Gernelle, 84120 Pertuis ,FRANCE",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST headquarters</h3><p>125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE.  +33 (0) 4 90 09 47 90</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Londres",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  UK & Ireland</h3><p>Luc Mallinger - Phone: +44 77 03 61 18 27     contact.uk@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Wroclaw",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST Poland, Central & Eastern Europe</h3><p> Rafal Firgang   -  Phone: +48 692 388 946      contact.cee@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Saragosse, Espagne",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Spain & Portugal</h3><p> José Luis Izquierdo  -  Phone: +34 620 296 739     contact.spain@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "São Paulo, Brésil",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Brazil</h3><p>Etimo Ferreira   -  Phone: +55 11 975 961 068       contact-brasil@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Japan 〒100-8111 Tōkyō-to, Chiyoda-ku, Uchikanda, 1 Chome−5−15",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST   Japan KK</h3><p>Yoshifumi Kato -       Arte Otemachi 10F 1-5-16 Uchikanda, Chiyoda-ku TOKYO 101-0047 JAPAN      PHONE : +81 3 3233 2150 contact.japan@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "1299 Schlumberger Drive Fort Mill SC 29715 USA",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  North America</h3><p>Gregor Veeser, Jeff Fountain, Greg Mattioli      -             1299 Schlumberger Drive Fort Mill SC 29715 USA     PHONE : +1 803 396 3990 contact.usa@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Bologna, italy",
# 							data: '<div class="gmap-infowindow-content"><h3>Pellenc ST  Italy</h3><p>Beppe Eliantonio   -   Phone: +39 349 6161 359 contact.italy@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Mexico city, mexico",
# 							data: '<div class="gmap-infowindow-content"><h3>Mexico</h3><p>contact.mexico@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Turkey",
# 							data: '<div class="gmap-infowindow-content"><h3>Turkey</h3><p>contact.turkey@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Israel",
# 							data: '<div class="gmap-infowindow-content"><h3>Israel</h3><p>contact.israel@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "South Korea",
# 							data: '<div class="gmap-infowindow-content"><h3>South Korea</h3><p>contact.southkorea@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "shanghai, china",
# 							data: '<div class="gmap-infowindow-content"><h3>China</h3><p>contact.china@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "New York, USA",
# 							data: '<div class="gmap-infowindow-content"><h3>North America</h3><p></p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 				],
# 				options:{
# 					draggable: false
# 				},
# 				events:{
# 					click: function(marker, event, context){
# 						var map = jQuery(this).gmap3("get"),
# 						infowindow = jQuery(this).gmap3({ get:{ name:"infowindow" } });
# 						if (infowindow){
# 							infowindow.open(map, marker);
# 							infowindow.setContent(context.data);
# 						} else {
# 							jQuery(this).gmap3({
# 								infowindow:{
# 									anchor:marker,
# 									options:{ content: context.data }
# 								}
# 							});
# 						}
# 					},
# 				},
# 			}
# 		});
#
# 			if(!isResponsive(1024)){
# 				jQuery("#elm-google-map-35").waypoint(function(){
# 					jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 				}, { triggerOnce: true, offset: "95%" });
# 			} else {
# 				jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 			}
# 	});, prashant_balan@apple.com, If you did not receive a copy of the PHP license, or have any questions about PHP licensing, please contact license@php.net., office@photonic.at
# Unable to open this link: http://www.psplc.com
# Unable to open this link: www.photontec-berlin.com
# The server couldn't fulfill the request for http://www.photox.co.uk.
# Error code:  404
# Unable to open this link: http://www.photox.co.uk
# The server couldn't fulfill the request for http://www.itn.liu.se/english/.
# Error code:  404
# The server couldn't fulfill the request for http://www.up.univ-mrs.fr/wpiim.
# Error code:  404
# jQuery(window).load(function(){
#
# 		var styles = [
# 			{
# 				stylers: [
# 					{ hue: "#596b79" },
# 					{ saturation: "-50" },
# 					{ lightness: "0" },
# 				]
# 			},
# 			{ featureType: "landscape", stylers: [
# 					{ hue: "#3f7644"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "administrative", stylers: [
# 					{ hue: "#76723f"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "road", stylers: [
# 					{ hue: "#c9aa78"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "water", stylers: [
# 					{ hue: ""},
# 					{ saturation: ""},
# 					{ lightness: ""},
# 				]
# 			},
# 			{ featureType: "poi", stylers: [
# 					{ hue: "#7a6d3d"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 		];
#
# 		jQuery("#elm-google-map-35-container").gmap3({
# 			map:{
# 				address: '125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE',
# 				options:{
#
# 					mapTypeId: google.maps.MapTypeId.ROADMAP,
# 					zoom: 2,
# 					scrollwheel: false,
# 					styles: styles,
# 				}
# 			},
# 			marker:{
# 				values:[
# 											{
# 							address: "125, rue François Gernelle, 84120 Pertuis ,FRANCE",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST headquarters</h3><p>125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE.  +33 (0) 4 90 09 47 90</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Londres",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  UK & Ireland</h3><p>Luc Mallinger - Phone: +44 77 03 61 18 27     contact.uk@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Wroclaw",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST Poland, Central & Eastern Europe</h3><p> Rafal Firgang   -  Phone: +48 692 388 946      contact.cee@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Saragosse, Espagne",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Spain & Portugal</h3><p> José Luis Izquierdo  -  Phone: +34 620 296 739     contact.spain@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "São Paulo, Brésil",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Brazil</h3><p>Etimo Ferreira   -  Phone: +55 11 975 961 068       contact-brasil@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Japan 〒100-8111 Tōkyō-to, Chiyoda-ku, Uchikanda, 1 Chome−5−15",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST   Japan KK</h3><p>Yoshifumi Kato -       Arte Otemachi 10F 1-5-16 Uchikanda, Chiyoda-ku TOKYO 101-0047 JAPAN      PHONE : +81 3 3233 2150 contact.japan@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "1299 Schlumberger Drive Fort Mill SC 29715 USA",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  North America</h3><p>Gregor Veeser, Jeff Fountain, Greg Mattioli      -             1299 Schlumberger Drive Fort Mill SC 29715 USA     PHONE : +1 803 396 3990 contact.usa@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Bologna, italy",
# 							data: '<div class="gmap-infowindow-content"><h3>Pellenc ST  Italy</h3><p>Beppe Eliantonio   -   Phone: +39 349 6161 359 contact.italy@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Mexico city, mexico",
# 							data: '<div class="gmap-infowindow-content"><h3>Mexico</h3><p>contact.mexico@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Turkey",
# 							data: '<div class="gmap-infowindow-content"><h3>Turkey</h3><p>contact.turkey@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Israel",
# 							data: '<div class="gmap-infowindow-content"><h3>Israel</h3><p>contact.israel@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "South Korea",
# 							data: '<div class="gmap-infowindow-content"><h3>South Korea</h3><p>contact.southkorea@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "shanghai, china",
# 							data: '<div class="gmap-infowindow-content"><h3>China</h3><p>contact.china@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "New York, USA",
# 							data: '<div class="gmap-infowindow-content"><h3>North America</h3><p></p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 				],
# 				options:{
# 					draggable: false
# 				},
# 				events:{
# 					click: function(marker, event, context){
# 						var map = jQuery(this).gmap3("get"),
# 						infowindow = jQuery(this).gmap3({ get:{ name:"infowindow" } });
# 						if (infowindow){
# 							infowindow.open(map, marker);
# 							infowindow.setContent(context.data);
# 						} else {
# 							jQuery(this).gmap3({
# 								infowindow:{
# 									anchor:marker,
# 									options:{ content: context.data }
# 								}
# 							});
# 						}
# 					},
# 				},
# 			}
# 		});
#
# 			if(!isResponsive(1024)){
# 				jQuery("#elm-google-map-35").waypoint(function(){
# 					jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 				}, { triggerOnce: true, offset: "95%" });
# 			} else {
# 				jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 			}
# 	});, prashant_balan@apple.com, If you did not receive a copy of the PHP license, or have any questions about PHP licensing, please contact license@php.net., office@photonic.at, info@pi.ws
# The server couldn't fulfill the request for http://pi4.de/.
# Error code:  404
# Unable to open this link: http://pi4.de/
# The server couldn't fulfill the request for http://www.picogiga.com#http://www.picogiga.com#.
# Error code:  404
# Unable to open this link: www.plasmachem.com
# Unable to open this link: www.plasmachem.com
# The server couldn't fulfill the request for http://www.plassys.com.
# Error code:  404
# Unable to open this link: http://www.plassys.com
# The server couldn't fulfill the request for http://www.perfos.com/index.htm.
# Error code:  404
# Unable to open this link: http://www.pms-optik.de
# jQuery(window).load(function(){
#
# 		var styles = [
# 			{
# 				stylers: [
# 					{ hue: "#596b79" },
# 					{ saturation: "-50" },
# 					{ lightness: "0" },
# 				]
# 			},
# 			{ featureType: "landscape", stylers: [
# 					{ hue: "#3f7644"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "administrative", stylers: [
# 					{ hue: "#76723f"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "road", stylers: [
# 					{ hue: "#c9aa78"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "water", stylers: [
# 					{ hue: ""},
# 					{ saturation: ""},
# 					{ lightness: ""},
# 				]
# 			},
# 			{ featureType: "poi", stylers: [
# 					{ hue: "#7a6d3d"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 		];
#
# 		jQuery("#elm-google-map-35-container").gmap3({
# 			map:{
# 				address: '125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE',
# 				options:{
#
# 					mapTypeId: google.maps.MapTypeId.ROADMAP,
# 					zoom: 2,
# 					scrollwheel: false,
# 					styles: styles,
# 				}
# 			},
# 			marker:{
# 				values:[
# 											{
# 							address: "125, rue François Gernelle, 84120 Pertuis ,FRANCE",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST headquarters</h3><p>125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE.  +33 (0) 4 90 09 47 90</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Londres",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  UK & Ireland</h3><p>Luc Mallinger - Phone: +44 77 03 61 18 27     contact.uk@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Wroclaw",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST Poland, Central & Eastern Europe</h3><p> Rafal Firgang   -  Phone: +48 692 388 946      contact.cee@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Saragosse, Espagne",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Spain & Portugal</h3><p> José Luis Izquierdo  -  Phone: +34 620 296 739     contact.spain@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "São Paulo, Brésil",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Brazil</h3><p>Etimo Ferreira   -  Phone: +55 11 975 961 068       contact-brasil@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Japan 〒100-8111 Tōkyō-to, Chiyoda-ku, Uchikanda, 1 Chome−5−15",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST   Japan KK</h3><p>Yoshifumi Kato -       Arte Otemachi 10F 1-5-16 Uchikanda, Chiyoda-ku TOKYO 101-0047 JAPAN      PHONE : +81 3 3233 2150 contact.japan@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "1299 Schlumberger Drive Fort Mill SC 29715 USA",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  North America</h3><p>Gregor Veeser, Jeff Fountain, Greg Mattioli      -             1299 Schlumberger Drive Fort Mill SC 29715 USA     PHONE : +1 803 396 3990 contact.usa@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Bologna, italy",
# 							data: '<div class="gmap-infowindow-content"><h3>Pellenc ST  Italy</h3><p>Beppe Eliantonio   -   Phone: +39 349 6161 359 contact.italy@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Mexico city, mexico",
# 							data: '<div class="gmap-infowindow-content"><h3>Mexico</h3><p>contact.mexico@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Turkey",
# 							data: '<div class="gmap-infowindow-content"><h3>Turkey</h3><p>contact.turkey@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Israel",
# 							data: '<div class="gmap-infowindow-content"><h3>Israel</h3><p>contact.israel@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "South Korea",
# 							data: '<div class="gmap-infowindow-content"><h3>South Korea</h3><p>contact.southkorea@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "shanghai, china",
# 							data: '<div class="gmap-infowindow-content"><h3>China</h3><p>contact.china@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "New York, USA",
# 							data: '<div class="gmap-infowindow-content"><h3>North America</h3><p></p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 				],
# 				options:{
# 					draggable: false
# 				},
# 				events:{
# 					click: function(marker, event, context){
# 						var map = jQuery(this).gmap3("get"),
# 						infowindow = jQuery(this).gmap3({ get:{ name:"infowindow" } });
# 						if (infowindow){
# 							infowindow.open(map, marker);
# 							infowindow.setContent(context.data);
# 						} else {
# 							jQuery(this).gmap3({
# 								infowindow:{
# 									anchor:marker,
# 									options:{ content: context.data }
# 								}
# 							});
# 						}
# 					},
# 				},
# 			}
# 		});
#
# 			if(!isResponsive(1024)){
# 				jQuery("#elm-google-map-35").waypoint(function(){
# 					jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 				}, { triggerOnce: true, offset: "95%" });
# 			} else {
# 				jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 			}
# 	});, prashant_balan@apple.com, If you did not receive a copy of the PHP license, or have any questions about PHP licensing, please contact license@php.net., office@photonic.at, info@pi.ws, info@polatis.com, div class="col-md-3">
# 					<h4 class="space10">Contact Polatis</h4>
# 			  <ul class="c-info">
# 						<li><i class="fa fa-map-marker"></i> 213 Burlington Road<br>Suite 123<br>Bedford, MA 01730
# 						</li>
# 						<li>
# 						</li>
# 						<li><i class="fa fa-phone"></i> +1.844.POLATIS</li>
# 						<li><i class="fa fa-envelope-o"></i> info@polatis.com</li>
# 					</ul>
# 					<div class="clearfix space10"></div>
# 				</div
# Unable to open this link: www.bow-brillenglas.de
# jQuery(window).load(function(){
#
# 		var styles = [
# 			{
# 				stylers: [
# 					{ hue: "#596b79" },
# 					{ saturation: "-50" },
# 					{ lightness: "0" },
# 				]
# 			},
# 			{ featureType: "landscape", stylers: [
# 					{ hue: "#3f7644"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "administrative", stylers: [
# 					{ hue: "#76723f"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "road", stylers: [
# 					{ hue: "#c9aa78"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "water", stylers: [
# 					{ hue: ""},
# 					{ saturation: ""},
# 					{ lightness: ""},
# 				]
# 			},
# 			{ featureType: "poi", stylers: [
# 					{ hue: "#7a6d3d"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 		];
#
# 		jQuery("#elm-google-map-35-container").gmap3({
# 			map:{
# 				address: '125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE',
# 				options:{
#
# 					mapTypeId: google.maps.MapTypeId.ROADMAP,
# 					zoom: 2,
# 					scrollwheel: false,
# 					styles: styles,
# 				}
# 			},
# 			marker:{
# 				values:[
# 											{
# 							address: "125, rue François Gernelle, 84120 Pertuis ,FRANCE",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST headquarters</h3><p>125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE.  +33 (0) 4 90 09 47 90</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Londres",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  UK & Ireland</h3><p>Luc Mallinger - Phone: +44 77 03 61 18 27     contact.uk@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Wroclaw",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST Poland, Central & Eastern Europe</h3><p> Rafal Firgang   -  Phone: +48 692 388 946      contact.cee@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Saragosse, Espagne",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Spain & Portugal</h3><p> José Luis Izquierdo  -  Phone: +34 620 296 739     contact.spain@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "São Paulo, Brésil",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Brazil</h3><p>Etimo Ferreira   -  Phone: +55 11 975 961 068       contact-brasil@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Japan 〒100-8111 Tōkyō-to, Chiyoda-ku, Uchikanda, 1 Chome−5−15",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST   Japan KK</h3><p>Yoshifumi Kato -       Arte Otemachi 10F 1-5-16 Uchikanda, Chiyoda-ku TOKYO 101-0047 JAPAN      PHONE : +81 3 3233 2150 contact.japan@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "1299 Schlumberger Drive Fort Mill SC 29715 USA",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  North America</h3><p>Gregor Veeser, Jeff Fountain, Greg Mattioli      -             1299 Schlumberger Drive Fort Mill SC 29715 USA     PHONE : +1 803 396 3990 contact.usa@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Bologna, italy",
# 							data: '<div class="gmap-infowindow-content"><h3>Pellenc ST  Italy</h3><p>Beppe Eliantonio   -   Phone: +39 349 6161 359 contact.italy@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Mexico city, mexico",
# 							data: '<div class="gmap-infowindow-content"><h3>Mexico</h3><p>contact.mexico@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Turkey",
# 							data: '<div class="gmap-infowindow-content"><h3>Turkey</h3><p>contact.turkey@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Israel",
# 							data: '<div class="gmap-infowindow-content"><h3>Israel</h3><p>contact.israel@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "South Korea",
# 							data: '<div class="gmap-infowindow-content"><h3>South Korea</h3><p>contact.southkorea@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "shanghai, china",
# 							data: '<div class="gmap-infowindow-content"><h3>China</h3><p>contact.china@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "New York, USA",
# 							data: '<div class="gmap-infowindow-content"><h3>North America</h3><p></p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 				],
# 				options:{
# 					draggable: false
# 				},
# 				events:{
# 					click: function(marker, event, context){
# 						var map = jQuery(this).gmap3("get"),
# 						infowindow = jQuery(this).gmap3({ get:{ name:"infowindow" } });
# 						if (infowindow){
# 							infowindow.open(map, marker);
# 							infowindow.setContent(context.data);
# 						} else {
# 							jQuery(this).gmap3({
# 								infowindow:{
# 									anchor:marker,
# 									options:{ content: context.data }
# 								}
# 							});
# 						}
# 					},
# 				},
# 			}
# 		});
#
# 			if(!isResponsive(1024)){
# 				jQuery("#elm-google-map-35").waypoint(function(){
# 					jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 				}, { triggerOnce: true, offset: "95%" });
# 			} else {
# 				jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 			}
# 	});, prashant_balan@apple.com, If you did not receive a copy of the PHP license, or have any questions about PHP licensing, please contact license@php.net., office@photonic.at, info@pi.ws, info@polatis.com, div class="col-md-3">
# 					<h4 class="space10">Contact Polatis</h4>
# 			  <ul class="c-info">
# 						<li><i class="fa fa-map-marker"></i> 213 Burlington Road<br>Suite 123<br>Bedford, MA 01730
# 						</li>
# 						<li>
# 						</li>
# 						<li><i class="fa fa-phone"></i> +1.844.POLATIS</li>
# 						<li><i class="fa fa-envelope-o"></i> info@polatis.com</li>
# 					</ul>
# 					<div class="clearfix space10"></div>
# 				</div, info@polydiagnost.com, info@polydiagnost.com | www.polydiagnost.com
# We failed to reach a server for http://www.polytech.se.
# Reason:  [Errno 8] nodename nor servname provided, or not known
# Unable to open this link: www.led-eshop.de
# The server couldn't fulfill the request for http://www.powerphotonic.co.uk.
# Error code:  404
# Unable to open this link: http://www.powerphotonic.co.uk
# Unable to open this link: www.prc-krochmann.de
# The server couldn't fulfill the request for http://www.precitec.de.
# Error code:  404
# Unable to open this link: http://www.precitec.de
# The server couldn't fulfill the request for http://fr.precitec.de/.
# Error code:  404
# Unable to open this link: http://fr.precitec.de/
# The server couldn't fulfill the request for http://www.precitech.com.
# Error code:  404
# Unable to open this link: http://www.precitech.com
# jQuery(window).load(function(){
#
# 		var styles = [
# 			{
# 				stylers: [
# 					{ hue: "#596b79" },
# 					{ saturation: "-50" },
# 					{ lightness: "0" },
# 				]
# 			},
# 			{ featureType: "landscape", stylers: [
# 					{ hue: "#3f7644"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "administrative", stylers: [
# 					{ hue: "#76723f"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "road", stylers: [
# 					{ hue: "#c9aa78"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 			{ featureType: "water", stylers: [
# 					{ hue: ""},
# 					{ saturation: ""},
# 					{ lightness: ""},
# 				]
# 			},
# 			{ featureType: "poi", stylers: [
# 					{ hue: "#7a6d3d"},
# 					{ saturation: " -40 "},
# 					{ lightness: " 0 "},
# 				]
# 			},
# 		];
#
# 		jQuery("#elm-google-map-35-container").gmap3({
# 			map:{
# 				address: '125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE',
# 				options:{
#
# 					mapTypeId: google.maps.MapTypeId.ROADMAP,
# 					zoom: 2,
# 					scrollwheel: false,
# 					styles: styles,
# 				}
# 			},
# 			marker:{
# 				values:[
# 											{
# 							address: "125, rue François Gernelle, 84120 Pertuis ,FRANCE",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST headquarters</h3><p>125 Rue François Gernelle, 84124 PERTUIS CEDEX 4 ,FRANCE.  +33 (0) 4 90 09 47 90</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Londres",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  UK & Ireland</h3><p>Luc Mallinger - Phone: +44 77 03 61 18 27     contact.uk@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Wroclaw",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST Poland, Central & Eastern Europe</h3><p> Rafal Firgang   -  Phone: +48 692 388 946      contact.cee@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Saragosse, Espagne",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Spain & Portugal</h3><p> José Luis Izquierdo  -  Phone: +34 620 296 739     contact.spain@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "São Paulo, Brésil",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  Brazil</h3><p>Etimo Ferreira   -  Phone: +55 11 975 961 068       contact-brasil@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Japan 〒100-8111 Tōkyō-to, Chiyoda-ku, Uchikanda, 1 Chome−5−15",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST   Japan KK</h3><p>Yoshifumi Kato -       Arte Otemachi 10F 1-5-16 Uchikanda, Chiyoda-ku TOKYO 101-0047 JAPAN      PHONE : +81 3 3233 2150 contact.japan@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "1299 Schlumberger Drive Fort Mill SC 29715 USA",
# 							data: '<div class="gmap-infowindow-content"><h3>PELLENC ST  North America</h3><p>Gregor Veeser, Jeff Fountain, Greg Mattioli      -             1299 Schlumberger Drive Fort Mill SC 29715 USA     PHONE : +1 803 396 3990 contact.usa@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/marker-md-e1421058595685.png"
# 							}
# 						},
# 						{
# 							address: "Bologna, italy",
# 							data: '<div class="gmap-infowindow-content"><h3>Pellenc ST  Italy</h3><p>Beppe Eliantonio   -   Phone: +39 349 6161 359 contact.italy@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/map-marker-hi-e1421058994230.png"
# 							}
# 						},
# 						{
# 							address: "Mexico city, mexico",
# 							data: '<div class="gmap-infowindow-content"><h3>Mexico</h3><p>contact.mexico@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Turkey",
# 							data: '<div class="gmap-infowindow-content"><h3>Turkey</h3><p>contact.turkey@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "Israel",
# 							data: '<div class="gmap-infowindow-content"><h3>Israel</h3><p>contact.israel@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "South Korea",
# 							data: '<div class="gmap-infowindow-content"><h3>South Korea</h3><p>contact.southkorea@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "shanghai, china",
# 							data: '<div class="gmap-infowindow-content"><h3>China</h3><p>contact.china@pellencst.com</p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 						{
# 							address: "New York, USA",
# 							data: '<div class="gmap-infowindow-content"><h3>North America</h3><p></p></div>',
# 							options:
# 							{
# 								icon: "http://www.pellencst.com/wp-content/uploads/2015/01/yellow-marker-black-border-hi-e1421059551726.png"
# 							}
# 						},
# 				],
# 				options:{
# 					draggable: false
# 				},
# 				events:{
# 					click: function(marker, event, context){
# 						var map = jQuery(this).gmap3("get"),
# 						infowindow = jQuery(this).gmap3({ get:{ name:"infowindow" } });
# 						if (infowindow){
# 							infowindow.open(map, marker);
# 							infowindow.setContent(context.data);
# 						} else {
# 							jQuery(this).gmap3({
# 								infowindow:{
# 									anchor:marker,
# 									options:{ content: context.data }
# 								}
# 							});
# 						}
# 					},
# 				},
# 			}
# 		});
#
# 			if(!isResponsive(1024)){
# 				jQuery("#elm-google-map-35").waypoint(function(){
# 					jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 				}, { triggerOnce: true, offset: "95%" });
# 			} else {
# 				jQuery("#elm-google-map-35").parent().parent().addClass('load-finished');
# 			}
# 	});, prashant_balan@apple.com, If you did not receive a copy of the PHP license, or have any questions about PHP licensing, please contact license@php.net., office@photonic.at, info@pi.ws, info@polatis.com, div class="col-md-3">
# 					<h4 class="space10">Contact Polatis</h4>
# 			  <ul class="c-info">
# 						<li><i class="fa fa-map-marker"></i> 213 Burlington Road<br>Suite 123<br>Bedford, MA 01730
# 						</li>
# 						<li>
# 						</li>
# 						<li><i class="fa fa-phone"></i> +1.844.POLATIS</li>
# 						<li><i class="fa fa-envelope-o"></i> info@polatis.com</li>
# 					</ul>
# 					<div class="clearfix space10"></div>
# 				</div, info@polydiagnost.com, info@polydiagnost.com | www.polydiagnost.com, Kirk.Rogers@ametek.com, Mike.Wilson@ametek.com, Zi.Bei.Zhang@ametek.com.cn, Jun.Cai@ametek.com.cn, Dieter.Marschall@ametek.com, tobias.helmus@ametek.com, Murugesh.Thimmanna@ametek.com, Mike.Tanniru@Ametek.com, Mitsuharu.Nakagiri@ametek.co.jp, Jinhokim@samjoongoptical.com, ptan@cairnhill.com, Sales@syms.com.tw, Zi.Zei.Zhang@ametek.com.cn, Peter.Chilcott@ametek.com, Tsutomu.Miyashita@ametek.co.jp, Fadi.Achkouti@ametek.com, paul.munteanu@storelogistic.ro, it.info@primaelectro.com, uk.info@primaelectro.com, us.info@primaelectro.com, cn.info@primaelectro.com, info@primapower.com, E-mail: sales@imts.com.au, E-mail: pedro.iturriaga@proingas.cl, E-mail: lucascena@cenasrl.com.ar, E-mail: sales@ifexport.com, E-mail: ba-gi@bezequint.net, E-mail: info@promac.com.gr, E-mail: pahor@ferrojulia.it, E-mail: info@lorsel.com, E-mail: info@carveron.hu, E-mail: info@canmet.sk, E-mail: info@canmet.cz, E-mail: info@toolpress.com.ua, E-mail: eerik@tootmisseadmed.ee, E-mail: info@dinmaskin.se, E-mail: post@dinmaskin.no, E-mail: info@maskingruppen.dk, E-mail: info@looser-maschinen.ch, E-mail: mail@tuwi.nl, E-mail: info@nande.pt, E-mail: comercial@best-tech.info, E-mail: jac@jinacom.com, E-mail: info@dynamics.com.tw, E-mail: sales@leeport.com.hk, E-mail: sales@javatec-machinery.com, E-mail: patricklee@leeport.com.sg, E-mail: mail@numac.com.my, info@vinamachines.com, E-mail: tony@hsm.co.th, E-mail: susan_behravan@hotmail.com, E-mail: franco@talmac.co.za, E-mail: sayed_fathy@valuetechnologies.net, E-mail: info.br@primapower.com, E-mail: us.sales@primapower.com, E-mail: lds.sales@primapower.com, E-mail: kr.service@primapower.com, sales@cn.primapower.com, E-mail: india.support@primapower.com, E-mail: pl.info@primapower.com, E-mail: tr.service@primapower.com; tr.sales@primapower.com, E-mail: hu.service@primapower.com, E-mail: cz.service@primapower.com, E-mail: de.info@primapower.com, E-mail: siegfried.kaeppeler@primapower.com; rene.brunner@primapower.com, E-mail: es.info@primapower.com, E-mail: commercial.fr@primapower.com, E-mail: info.benelux@primapower.com, E-mail: info.uk@primapower.com, E-mail: ru.sales@primapower.com – for Sales ru.service@primapower.com – for Service ru.spares@primapower.com – for Spare Parts, E-mail: Michael.Shahidiar@PrimaPower.com, E-mail: mindaugas.vasiliauskas@primapower.com (sales); linas.petkevicius@primapower.com (service), E-mail: it.sales@primapower.com, E-mail: us.info@primapower.com
# The server couldn't fulfill the request for http://www.primes.de.
# Error code:  404
# Unable to open this link: http://www.primes.de
